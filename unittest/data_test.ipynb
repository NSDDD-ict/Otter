# %%
import json 
path = "/mnt/bn/ecom-govern-maxiangqian-lq/lj/Otter/output/FunQA.json"
datas = json.load(open(path, "r"))

# %%
for key in datas.keys():
    if 'M_Z_297_0000_0170_0000' in key:
        print(key)
        break
# Out:
# FunQA_IMG_M_Z_297_0000_0170_0000

# %%
import pandas as pd
import json
datas = []

with open('/mnt/bn/ecom-govern-maxiangqian-lq/projects/public_projects/live_content_big_model/gpt_audit_benchmark/scene/all/cot/human_label_train_data/train_7w_neg_data/audit_LLM_train_neg_0810_gpt_clean.jsonl', 'r') as f:
    for data in f:
        datas.append(json.loads(data))

# %%
datas[0]
# Out:
# {'project_id': 7171261466513834503,
#  'task_id': 7259777703061029387,
#  'label': 0,
#  'verify_reason': '',
#  'voice_text': '所以看姐姐们喜欢哪一个，每一款都是设计感啊，设计感满满的，设计感满满的啊，上身效果很美的，姐姐们有喜欢哪一个可以帮你们来上身效？<br/>看一下啊，姐妹可以逛一下小黄车啊，小黄车里都是性价比很高的。<br/>姐姐们看看这么一手耳钉都没有喜欢的吗？一千三百八的戒指，姐姐是那个？你说是葫芦呢？还是那个？',
#  'ocr_text': '',
# ...
